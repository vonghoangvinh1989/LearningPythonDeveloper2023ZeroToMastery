# %%
import pandas as pd
data_frame = pd.read_csv('data.csv')
data_frame
# Out:
#            ID            Name  Age  \
# 0      176580       L. Suárez   29
# 1      178518   R. Nainggolan   28
# 2      181872        A. Vidal   29
# 3      197445        D. Alaba   24
# 4      195864        P. Pogba   23
# ...       ...             ...  ...
# 17555  233215        C. Addai   18
# 17556  232911     R. Kamiyama   31
# 17557  235387         B. Gaye   18
# 17558  237904   K. Olifirenko   18
# 17559  237463       A. Kelsey   16
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1      https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2      https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3      https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4      https://cdn.sofifa.com/players/195/864/17_60.png      France
# ...                                                 ...         ...
# ...

# %%
data_frame.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   17560.000000  17560.000000  17560.000000  17560.000000  17560.000000
# mean   205606.310308     24.576310     66.155125     70.938326   1595.468223
# std     33102.038643      4.653748      7.013210      6.140487    269.862012
# min        16.000000     15.000000     45.000000     45.000000    751.000000
# 25%    191486.000000     21.000000     62.000000     67.000000   1452.000000
# 50%    212936.000000     24.000000     66.000000     71.000000   1633.000000
# 75%    229670.000000     28.000000     71.000000     75.000000   1786.000000
# max    241056.000000     46.000000     94.000000     94.000000   2291.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              17560.000000  17560.000000  17560.000000   17541.000000
# mean                   1.111902      2.935820      2.305410      20.411265
# ...

# %%
data_frame.values
# Out:
# array([[176580, ' L. Suárez', 29, ..., 37.0, 'ST', 88.0],
#        [178518, ' R. Nainggolan', 28, ..., 11.0, 'CDM', 84.0],
#        [181872, ' A. Vidal', 29, ..., 4.0, 'CDM', 85.0],
#        ...,
#        [235387, ' B. Gaye', 18, ..., 58.0, 'GK', 52.0],
#        [237904, ' K. Olifirenko', 18, ..., 49.0, 'GK', 49.0],
#        [237463, ' A. Kelsey', 16, ..., 48.0, 'GK', 45.0]], dtype=object)

# %%
data_frame[data_frame["Age"]>40].head()
# Out:
#            ID              Name  Age  \
# 15482  140029          O. Pérez   43
# 16028  146527           Esteban   41
# 16590  188033      E. El-Hadary   43
# 16747   51503         B. Jensen   41
# 16893    7939   J. Jääskeläinen   41
#
#                                                   Photo Nationality  \
# 15482  https://cdn.sofifa.com/players/140/029/17_60.png      Mexico
# 16028  https://cdn.sofifa.com/players/146/527/17_60.png       Spain
# 16590  https://cdn.sofifa.com/players/188/033/17_60.png       Egypt
# 16747  https://cdn.sofifa.com/players/051/503/17_60.png     Denmark
# 16893  https://cdn.sofifa.com/players/007/939/17_60.png     Finland
#
#                                       Flag  Overall  Potential  \
# 15482  https://cdn.sofifa.com/flags/mx.png       71         71
# 16028  https://cdn.sofifa.com/flags/es.png       68         68
# 16590  https://cdn.sofifa.com/flags/eg.png       74         74
# 16747  https://cdn.sofifa.com/flags/dk.png       58         58
# ...

# %%
data_frame["Best Position"].unique()
# Out:
# array(['ST', 'CDM', 'LB', 'CAM', 'RB', 'LWB', 'CM', 'RWB', 'RM', 'LM',
#        'CB', 'LW', 'CF', 'RW', 'GK'], dtype=object)

# %%
data_frame["Nationality"].unique()
# Out:
# array(['Uruguay', 'Belgium', 'Chile', 'Austria', 'France', 'Wales',
#        'Italy', 'England', 'Croatia', 'Portugal', 'Spain', 'Brazil',
#        'Switzerland', 'Turkey', 'Ivory Coast', 'Ecuador', 'Serbia',
#        'Germany', 'Slovakia', 'Bosnia Herzegovina', 'Netherlands',
#        'Ghana', 'Armenia', 'Argentina', 'Russia', 'Finland', 'Mexico',
#        'Poland', 'Morocco', 'Benin', 'Colombia', 'Denmark', 'Sweden',
#        'Ukraine', 'Greece', 'United States', 'Senegal', 'Kenya',
#        'Curacao', 'Iceland', 'Czech Republic', 'Republic of Ireland',
#        'Israel', 'Gabon', 'Venezuela', 'Algeria', 'South Africa',
#        'Canada', 'Costa Rica', 'Nigeria', 'Moldova', 'Norway',
#        'Saudi Arabia', 'Honduras', 'Cuba', 'Paraguay', 'Korea Republic',
#        'Japan', 'Australia', 'Slovenia', 'Peru', 'Mali',
#        'Northern Ireland', 'Scotland', 'Guinea', 'Iraq', 'Egypt',
#        'Hungary', 'Cameroon', 'DR Congo', 'Albania', 'Romania', 'Tunisia',
# ...

# %%
data_frame["Age"].hist()
# Out:
# <Axes: >

# %%
data_frame["Name"].head(10)
# Out:
# 0             L. Suárez
# 1         R. Nainggolan
# 2              A. Vidal
# 3              D. Alaba
# 4              P. Pogba
# 5               G. Bale
# 6           A. Florenzi
# 7             L. Baines
# 8             L. Modrić
# 9     Cristiano Ronaldo
# Name: Name, dtype: object

# %%
data_frame.sort_values("Age", ascending=False).head()
# Out:
#            ID            Name  Age  \
# 17482   11728   B. Richardson   46
# 17403     645    D. Andersson   43
# 16590  188033    E. El-Hadary   43
# 15482  140029        O. Pérez   43
# 17194  167078     M. Hugosson   42
#
#                                                   Photo Nationality  \
# 17482  https://cdn.sofifa.com/players/011/728/17_60.png     England
# 17403  https://cdn.sofifa.com/players/000/645/17_60.png      Sweden
# 16590  https://cdn.sofifa.com/players/188/033/17_60.png       Egypt
# 15482  https://cdn.sofifa.com/players/140/029/17_60.png      Mexico
# 17194  https://cdn.sofifa.com/players/167/078/17_60.png      Sweden
#
#                                           Flag  Overall  Potential  \
# 17482  https://cdn.sofifa.com/flags/gb-eng.png       45         45
# 17403      https://cdn.sofifa.com/flags/se.png       57         57
# 16590      https://cdn.sofifa.com/flags/eg.png       74         74
# 15482      https://cdn.sofifa.com/flags/mx.png       71         71
# ...

# %%
nationality_group = data_frame.groupby("Nationality")
nationality_group.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13116\2438058845.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   nationality_group.mean()
#                               ID        Age    Overall  Potential  \
# Nationality
# Afghanistan        223989.000000  19.000000  55.000000  71.000000
# Albania            206047.000000  23.459459  66.027027  71.054054
# Algeria            197590.941176  25.960784  71.411765  74.313725
# Angola             202530.454545  25.454545  70.272727  73.727273
# Antigua & Barbuda  183940.500000  25.750000  62.750000  65.750000
# ...                          ...        ...        ...        ...
# Uzbekistan         194269.000000  28.000000  69.000000  69.000000
# Venezuela          211125.155556  24.111111  69.133333  74.022222
# ...

# %%
df1 = pd.DataFrame(data_frame, columns=['Name','Wage', 'Value'])

def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

wage = df1['Wage'].replace('[\€,]', '', regex=True).apply(value_to_float)
value = df1['Value'].replace('[\€,]', '', regex=True).apply(value_to_float)

df1['Wage'] = wage
df1['Value'] = value

df1['difference'] = df1['Value'] - df1['Wage']
df1.sort_values('difference', ascending=False)
# Out:
#                      Name      Wage        Value   difference
# 168                Neymar  450000.0  106000000.0  105550000.0
# 58               L. Messi  575000.0   89000000.0   88425000.0
# 9       Cristiano Ronaldo  575000.0   87000000.0   86425000.0
# 0               L. Suárez  525000.0   83000000.0   82475000.0
# 5                 G. Bale  375000.0   72000000.0   71625000.0
# ...                   ...       ...          ...          ...
# 763              W. Ayoví   20000.0          0.0     -20000.0
# 12554             C. Hill   20000.0          0.0     -20000.0
# 9464        M. Wasilewski   30000.0          0.0     -30000.0
# 2305               Hilton   30000.0          0.0     -30000.0
# 10402          G. McAuley   30000.0          0.0     -30000.0
#
# [17560 rows x 4 columns]

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='Wage', y='Value', data=df1)
graph
# Out:
# <Axes: xlabel='Wage', ylabel='Value'>

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name")]
)

p = figure(title="Soccer 2023", x_axis_label='Wage', y_axis_label="Value", plot_width=700, plot_height=700, tools=[TOOLTIPS])
p.circle('Wage', 'Value', size=10, source=df1)
show(p)
